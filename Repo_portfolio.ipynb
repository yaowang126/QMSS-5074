# %% [markdown]
# We have 3 projects this repo, which are:
# 1.   Predicting Happiness
# 2.   Brain Tumor Classification
# 3.   BBC News Category Classification

# %% [markdown]
# Predict World Happiness Rankings
#
# In this project, we analyzed what makes the citizens of one country more happy than the citizens of other countries, the data is consist of the happiness level of each country and 6 variables that discribe featrues of countries. The example of original data showed below. This project is a classification probelm of categorical Y with x as some real numbers. In this report we use Randomforest, method SVM method and plain-NN method. The best one here is SVM method.
# Github link: https://github.com/yaowang126/QMSS-5074/blob/master/Predicting_Happiness_Mini_Hackithon_for_tabular_data.ipynb

# %%
import pandas as pd
data=pd.read_csv("worldhappiness2019.csv")
data.head()
# Out:
#   Happiness_level Country or region  ...  Generosity  Perceptions of corruption
# 0       Very High           Finland  ...       0.153                      0.393
# 1       Very High           Denmark  ...       0.252                      0.410
# 2       Very High            Norway  ...       0.271                      0.341
# 3       Very High           Iceland  ...       0.354                      0.118
# 4       Very High       Netherlands  ...       0.322                      0.298
#
# [5 rows x 8 columns]

# %% [markdown]
# Brain Tumor Classification:
#
# This project is a classification project with image data. Here Y is categorical data, X is image, the examples of images show below. In this project we implemented plain-NN model, CNN model and transform learning from pretrained VGG16 model.
# Github link: https://github.com/yaowang126/QMSS-5074/blob/master/Write%20up%20a%20report%20that%20makes%20use%20of%20brain%20tumor%20diagnostic%20MRI%20image%20data.ipynb

# %%
import sys
import time
import cv2
import numpy as np
from matplotlib import pyplot as plt
import tensorflow as tf
import os
import zipfile
# !unzip brain_tumor_dataset.zip 
base_path = 'brain_tumor_dataset'
categories = ['yes', 'no']
fnames = []
for category in categories:
    image_folder = os.path.join(base_path, category)
    file_names = os.listdir(image_folder)
    full_path = [os.path.join(image_folder, file_name) for file_name in file_names]
    fnames.append(full_path)
    from keras.preprocessing import image
from keras.preprocessing.image import load_img
import numpy as np
from PIL import Image
def load_image(img_path):
        img = Image.open(img_path).convert("RGB").resize((224,224)) # import image, make sure it's RGB and resize to height and width you want.
        img = (np.float32(img)-np.float32(img).min())/(np.float32(img).max()-np.float32(img).min()) # min max transformation
        img=img.reshape((224,224,3)) # Create final shape as array with correct dimensions for Keras
        return img
preprocessed_image_data=list(map(load_image, fnames[0]+fnames[1])) 
X= np.array(preprocessed_image_data)
# Create y
from itertools import repeat

yes=list(repeat("yes", 155))
no=list(repeat("no", 98))
y_labels = yes+no

import pandas as pd
y=pd.get_dummies(y_labels)

# %%
fig,ax=plt.subplots(2,4)
fig.set_size_inches(7,5)
for i in range(2):
    for j in range (4):
        l= np.random.randint(0,len(y_labels))
        ax[i,j].imshow(X[l])
        ax[i,j].set_title('Tumor: '+y_labels[l])
        
plt.tight_layout()

# %% [markdown]
# BBC News Category Classification:
#
# This project is a project on text classification, the data is all news in 5 categories from CNN, we can see it below. Meaning here Y is of 5 categories and X is text data. We first padding every sentence in X to length of 100 and then used plain-NN method, CNN method, LSTM and stacked LSTM method.
# Github link:https://github.com/yaowang126/QMSS-5074/blob/master/BBC%20News%20Category%20Classification%20Mini-Hackathon.ipynb

# %%
bbc=pd.read_csv("https://storage.googleapis.com/dataset-uploader/bbc/bbc-text.csv")
bbc.head(5)
# Out:
#         category                                               text
# 0           tech  tv future in the hands of viewers with home th...
# 1       business  worldcom boss  left books alone  former worldc...
# 2          sport  tigers wary of farrell  gamble  leicester say ...
# 3          sport  yeading face newcastle in fa cup premiership s...
# 4  entertainment  ocean s twelve raids box office ocean s twelve...
